# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Elias Box Office Supervisor**

# %% [markdown]
# *I am interested in Data Science becuase I want to better understand trends in ticket sales and ways to improve sales*

# %% [markdown]
# ### The code is cell 5 should execute a math equation 25 X 4 = 100

# %%
25*4
# Out:
# 100

# %% [markdown]
# 1. going to display numbered list
# 2. then show bulleted list
# 3. finally show a working hyperlink to google
#
# * there is nothing of importance here
# * just showing the ability
# * to create the bullets
#
# [This is going to be a link to google](https://www.google.com)
